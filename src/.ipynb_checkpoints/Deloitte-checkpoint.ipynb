# %% [markdown]
# # Deloitte
# ## Mission Analytics, Data Exercise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

# %%
male = pd.read_csv('../data/MA_Exer_PikesPeak_Males.txt', delimiter = '\t')
female = pd.read_csv('../data/MA_Exer_PikesPeak_Females.txt', delimiter = '\t')

# %% [markdown]
# # Explore

# %%
male
# Out:
#       Place  Div/Tot   Num                Name    Ag         Hometown  \
# 0         1     1/48     9        Joshua Kemei  22.0          Kenya .
# 1         2     2/48    35  George Kirwa Misoi  22.0          Kenya .
# 2         3     3/48     3          Jacob Frey  24.0        Oakton VA
# 3         4     1/96    49      Gurmessa Kumsa  27.0     Oxon Hill MD
# 4         5     4/48    31          Mike Baird  24.0       Ardmore PA
# ...     ...      ...   ...                 ...   ...              ...
# 1260   1261  200/201  2792   Kenneth Winkfield  49.0         Bowie MD
# 1261   1262    50/50    63         Thom Hunter  63.0  Gaithersburg MD
# 1262   1263    96/96  1547     Nicholas Kelsch  27.0  Gaithersburg MD
# 1263   1264  201/201  3330         Cliff Chiet  45.0  Gaithersburg MD
# 1264   1265    73/73   547      Robert Banning  57.0     Greenbelt MD
#
#       Gun Tim  Net Tim   Pace
# 0       28:48   28:47#   4:38
# 1       29:11   29:10#   4:42
# 2       29:38   29:37#   4:46
# 3       29:46   29:46#   4:48
# 4       30:31    30:30   4:55
# ...       ...      ...    ...
# 1260  1:35:50  1:30:29  14:34
# 1261  1:42:41  1:37:20  15:40
# 1262  1:43:00  1:37:50  15:45
# 1263  1:44:07  1:38:46  15:54
# 1264  1:43:47  1:40:38  16:12
#
# [1265 rows x 9 columns]

# %%
male.dtypes
# Out:
# Place         int64
# Div/Tot      object
# Num           int64
# Name         object
# Ag          float64
# Hometown     object
# Gun Tim      object
# Net Tim      object
# Pace         object
# dtype: object

# %%
female
# Out:
#       Place  Div/Tot   Num                Name    Ag         Hometown  \
# 0         1     1/86    30  Florence Jepkosgei  22.0          Kenya .
# 1         2     2/86     8    Eunice Chepkirui  21.0          Kenya .
# 2         3    1/247  3200        Elena Orlova  36.0  Gaithersburg MD
# 3         4    1/173     2  Susannah Kvasnicka  34.0   Great Falls VA
# 4         5    1/142     6         Casey Smith  26.0     Arlington VA
# ...     ...      ...   ...                 ...   ...              ...
# 1100   1101  247/247  1847      Alicia Maxwell  35.0    Germantown MD
# 1101   1102  110/110  2618       Regina Tenali  47.0  Gaithersburg MD
# 1102   1103  171/173   986      Nirmala Donley  32.0  Ellicott City M
# 1103   1104  172/173  1214       Heidi Gertner  34.0      Bethesda MD
# 1104   1105  173/173  2852     Deborah Zerwitz  33.0    Washington DC
#
#         Gun Tim  Net Tim   Pace
# 0         32:59   32:58#   5:19
# 1         33:14   33:13#   5:21
# 2         34:26   34:25#   5:33
# 3         34:43   34:42#   5:35
# 4         35:04    35:02   5:39
# ...         ...      ...    ...
# 1100    1:43:47  1:40:39  16:12
# 1101    1:50:31  1:45:22  16:58
# 1102  D 1:50:31  1:45:22  16:58
# 1103    1:46:49  1:46:49  17:12
# 1104    1:46:49  1:46:49  17:12
#
# [1105 rows x 9 columns]

# %%
female.dtypes
# Out:
# Place         int64
# Div/Tot      object
# Num           int64
# Name         object
# Ag          float64
# Hometown     object
# Gun Tim      object
# Net Tim      object
# Pace         object
# dtype: object

# %% [markdown]
# # Cleanup

# %%
### Clean times ###
def drop_func(x):
    keeps = ['1','2','3','4','5','6','7','8','9','0',':']
    for num in x:
        if num not in keeps:
            x = x.replace(num,'')
    return x

### Unifies time ###
def dateparse(x):
    if len(x)==5:
        return f'00:{x}'
    else:
        return f'0{x}'

### Converts string to seconds for ease-of-computation ###
def time_to_seconds(x):
    h,m,s = x.split(':')
    return int(s)+60*(int(m)+60*int(h))
    
### Converts seconds back into 'H:M:S' format ###
def seconds_to_time(x):
    conversion = timedelta(seconds=x)
    return conversion

# %%
# funcs = [drop_func, dateparse, time_to_seconds]
# datas = [male['Gun Tim'],male['Net Tim'],female['Gun Tim'],female['Net Tim']]
# for func in funcs:
#     for data in datas:
#         data = data.apply(func)

### Loops with the Apply method were not playing nice ###

male['Gun Tim'] = male['Gun Tim'].apply(drop_func)
male['Gun Tim'] = male['Gun Tim'].apply(dateparse)
male['Gun Tim'] = male['Gun Tim'].apply(time_to_seconds)

male['Net Tim'] = male['Net Tim'].apply(drop_func)
male['Net Tim'] = male['Net Tim'].apply(dateparse)
male['Net Tim'] = male['Net Tim'].apply(time_to_seconds)

female['Gun Tim'] = female['Gun Tim'].apply(drop_func)
female['Gun Tim'] = female['Gun Tim'].apply(dateparse)
female['Gun Tim'] = female['Gun Tim'].apply(time_to_seconds)

female['Net Tim'] = female['Net Tim'].apply(drop_func)
female['Net Tim'] = female['Net Tim'].apply(dateparse)
female['Net Tim'] = female['Net Tim'].apply(time_to_seconds)

# %%
### Difference between Gun Time and Net Time ###
male['Delta'] = male['Gun Tim'] - male['Net Tim']
female['Delta'] = female['Gun Tim'] - female['Net Tim']

### Split Div and Tot into different columns ###
def split_divtot(x):
    if type(x) == str:
        return x.split('/')
    else:
        return [np.nan, np.nan]

m_divtot = male['Div/Tot'].apply(split_divtot).to_list()
male[['Div','Tot']] = pd.DataFrame(m_divtot, columns = ['Div','Tot'])

f_divtot = female['Div/Tot'].apply(split_divtot).to_list()
female[['Div','Tot']] = pd.DataFrame(m_divtot, columns = ['Div','Tot'])

# %% [markdown]
# # New Datasets

# %%
male
# Out:
#       Place  Div/Tot   Num                Name    Ag         Hometown  \
# 0         1     1/48     9        Joshua Kemei  22.0          Kenya .
# 1         2     2/48    35  George Kirwa Misoi  22.0          Kenya .
# 2         3     3/48     3          Jacob Frey  24.0        Oakton VA
# 3         4     1/96    49      Gurmessa Kumsa  27.0     Oxon Hill MD
# 4         5     4/48    31          Mike Baird  24.0       Ardmore PA
# ...     ...      ...   ...                 ...   ...              ...
# 1260   1261  200/201  2792   Kenneth Winkfield  49.0         Bowie MD
# 1261   1262    50/50    63         Thom Hunter  63.0  Gaithersburg MD
# 1262   1263    96/96  1547     Nicholas Kelsch  27.0  Gaithersburg MD
# 1263   1264  201/201  3330         Cliff Chiet  45.0  Gaithersburg MD
# 1264   1265    73/73   547      Robert Banning  57.0     Greenbelt MD
#
#       Gun Tim  Net Tim   Pace  Delta  Div  Tot
# 0        1728     1727   4:38      1    1   48
# 1        1751     1750   4:42      1    2   48
# 2        1778     1777   4:46      1    3   48
# 3        1786     1786   4:48      0    1   96
# 4        1831     1830   4:55      1    4   48
# ...       ...      ...    ...    ...  ...  ...
# 1260     5750     5429  14:34    321  200  201
# 1261     6161     5840  15:40    321   50   50
# 1262     6180     5870  15:45    310   96   96
# 1263     6247     5926  15:54    321  201  201
# 1264     6227     6038  16:12    189   73   73
#
# [1265 rows x 12 columns]

# %%
female
# Out:
#       Place  Div/Tot   Num                Name    Ag         Hometown  \
# 0         1     1/86    30  Florence Jepkosgei  22.0          Kenya .
# 1         2     2/86     8    Eunice Chepkirui  21.0          Kenya .
# 2         3    1/247  3200        Elena Orlova  36.0  Gaithersburg MD
# 3         4    1/173     2  Susannah Kvasnicka  34.0   Great Falls VA
# 4         5    1/142     6         Casey Smith  26.0     Arlington VA
# ...     ...      ...   ...                 ...   ...              ...
# 1100   1101  247/247  1847      Alicia Maxwell  35.0    Germantown MD
# 1101   1102  110/110  2618       Regina Tenali  47.0  Gaithersburg MD
# 1102   1103  171/173   986      Nirmala Donley  32.0  Ellicott City M
# 1103   1104  172/173  1214       Heidi Gertner  34.0      Bethesda MD
# 1104   1105  173/173  2852     Deborah Zerwitz  33.0    Washington DC
#
#       Gun Tim  Net Tim   Pace  Delta  Div  Tot
# 0        1979     1978   5:19      1    1   48
# 1        1994     1993   5:21      1    2   48
# 2        2066     2065   5:33      1    3   48
# 3        2083     2082   5:35      1    1   96
# 4        2104     2102   5:39      2    4   48
# ...       ...      ...    ...    ...  ...  ...
# 1100     6227     6039  16:12    188   39   50
# 1101     6631     6322  16:58    309   57   73
# 1102     6631     6322  16:58    309  181  203
# 1103     6409     6409  17:12      0  195  214
# 1104     6409     6409  17:12      0  128  143
#
# [1105 rows x 12 columns]

# %% [markdown]
# # General statistics - Mean, Median, Range

# %%
print('Male------------')
m_stats = male['Net Tim'].describe().apply(seconds_to_time)
for stat, index in zip(m_stats[1:], m_stats.index[1:]):
    print(f'{index} : {str(stat)[7:]}')
print('Female------------')
f_stats = female['Net Tim'].describe().apply(seconds_to_time)
for stat, index in zip(f_stats[1:], f_stats.index[1:]):
    print(f'{index} : {str(stat)[7:]}')
# Out:
# Male------------
# mean : 00:52:07.950988
# std : 00:09:41.253684
# min : 00:28:47
# 25% : 00:45:43
# 50% : 00:51:23
# 75% : 00:57:49
# max : 01:40:38
# Female------------
# mean : 00:58:28.484163
# std : 00:09:53.888621
# min : 00:32:58
# 25% : 00:52:14
# 50% : 00:57:51
# 75% : 01:03:37
# max : 01:46:49

# %% [markdown]
# # Distribution

# %%
m_mean = np.mean(male['Net Tim'])
f_mean = np.mean(female['Net Tim'])

# %matplotlib inline
fig,axs = plt.subplots(2)

sns.distplot(male['Net Tim'], ax = axs[0]);
axs[0].axvline(m_mean,color='b', linestyle='--')
axs[0].set_title('Male Net Time Distribution')

sns.distplot(female['Net Tim'], ax = axs[1]);
axs[1].axvline(f_mean,color='b', linestyle='--')
axs[1].set_title('Female Net Time Distribution')

fig.tight_layout();

# %% [markdown]
# # Mode is impractical in a continuous-like time spread

# %% [markdown]
# # Difference between Net Time and Gun Time

# %%
male['Delta'].describe().round()
# Out:
# count    1265.0
# mean      150.0
# std        95.0
# min         0.0
# 25%        69.0
# 50%       185.0
# 75%       220.0
# max       469.0
# Name: Delta, dtype: float64

# %%
female['Delta'].describe().round()
# Out:
# count    1105.0
# mean      195.0
# std        89.0
# min         0.0
# 25%       181.0
# 50%       209.0
# 75%       239.0
# max       560.0
# Name: Delta, dtype: float64

# %%
fig,ax = plt.subplots()
sns.distplot(male['Delta'])
ax.axvline(male['Delta'].mean(),color='b', linestyle='--')
ax.set_title('Male Net Time Distribution');

# %%
fig,ax = plt.subplots()
sns.distplot(female['Delta'])
ax.axvline(female['Delta'].mean(),color='b', linestyle='--')
ax.set_title('Male Net Time Distribution');

# %% [markdown]
# ## There seems to be 4 distinct distributions that occur in both plots. Around 0, 75, 200, and 300.

# %%
female.dropna(inplace=True)
parse = (female['Delta'] >190) & (female['Delta'] <250)
female[parse]
# Out:
#       Place  Div/Tot   Num               Name    Ag         Hometown  Gun Tim  \
# 88       89   15/173   524      Debbie Austin  41.0    Kensington MD     3019
# 123     124   17/173   420       Lisa Hoffman  32.0     Rockville MD     3067
# 138     139   21/173  2393  Jennifer Schwartz  34.0     Rockville MD     3089
# 139     140   33/247   731   Sharon Carlstrom  35.0    Kensington MD     3090
# 144     145   16/142  1784     Lisa Magdaleno  27.0    Kensington MD     3106
# ...     ...      ...   ...                ...   ...              ...      ...
# 1079   1080    85/86  2016   Hiva Nesvaderani  23.0  Silver Spring M     5078
# 1082   1083  168/173  2219     Althea Raiford  34.0  Silver Spring M     5150
# 1083   1084  173/173  2989  Veronica Thurmond  43.0  Silver Spring M     5184
# 1095   1096  244/247  3274       Cynthia Wong  36.0     Rockville MD     5874
# 1096   1097  170/173  3353          Karen Liu  33.0       Potomac MD     5874
#
#       Net Tim   Pace  Delta  Div  Tot
# 88       2788   7:29    231   13  214
# 123      2855   7:40    212   19  201
# 138      2886   7:45    203   15   96
# 139      2886   7:45    204   22  214
# 144      2906   7:48    200   19  143
# ...       ...    ...    ...  ...  ...
# 1079     4868  13:04    210  173  201
# 1082     4925  13:13    225   55   73
# 1083     4964  13:19    220   22   28
# 115      2845     2841   7:38      4   16  201
# 117      2847     2844   7:38      3   15  143
# 118      2853     2846   7:38      7    8  132
# 129      2877     2869   7:42      8   17  143
# 131      2888     2884   7:45      4   20  203
# 141      2899     2897   7:47      2    1   19
# 152      2929     2925   7:51      4   27  214
# 180      2969     2964   7:57      5   21   96
# 286      3155     3154   8:28      1   46  201
# 297      3184     3179   8:32      5   60  214
# 420      3319     3314   8:54      5   33  132
# 846      3859     3853  10:21      6  136  203
# 1103     6409     6409  17:12      0  195  214
# 1104     6409     6409  17:12      0  128  143

# %% [markdown]
# ### Initial inspection reveals a relationship between Div and Delta columns

# %%
female_correlation = pd.DataFrame(pd.to_numeric(female['Div']), pd.to_numeric(female['Tot'])).reset_index()
female_correlation['Delta'] = female['Delta']

g = sns.PairGrid(female_correlation)
g.map(sns.scatterplot);

# %% [markdown]
# ### Results are not promising.

# %% [markdown]
# # Chris Doe vs. Top 10%

# %%
chris_doe = int(male[male['Name'] == 'Chris Doe']['Net Tim'].values[0])
ten_percent = int(male['Net Tim'].quantile(.1))
difference = int( chris_doe - ten_percent)

# %%
print(f'Chris Doe : {str(seconds_to_time(chris_doe))} \n90th percentile : {str(seconds_to_time(ten_percent))} \nDifference : {str(seconds_to_time(difference))}')
# Out:
# Chris Doe : 0:49:43
# 90th percentile : 0:41:04
# Difference : 0:08:39

# %% [markdown]
# ### Chris is 8 mins and 39 seconds slower than the top 10%

# %% [markdown]
# # Division Times

# %%
male_divs = male.groupby('Div')
means = pd.DataFrame(male_divs['Net Tim'].mean())

# %%
means.reset_index(inplace=True)
means['Div'] = means['Div'].apply(lambda x: int(x))
means = means.set_index('Div').sort_index(ascending=False)

# %%
means
# Out:
#          Net Tim
# Div
# 214  5377.000000
# 213  5193.000000
# 212  4620.000000
# 211  4340.000000
# 210  4318.000000
# ..           ...
# 5    2509.461538
# 4    2392.615385
# 3    2410.857143
# 2    2482.133333
# 1    2338.333333
#
# [214 rows x 1 columns]

# %%
fig, ax = plt.subplots()
ax.scatter(means.index, means['Net Tim'])
ax.set_xlabel('Divisions')
ax.set_ylabel('Seconds')
ax.set_title('Net Time per Division');

# %%
sns.regplot(means.index, means['Net Tim']);

# %%
import statsmodels.api as sm
lr = sm.OLS(means.index, means['Net Tim'])
reg = lr.fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.847
# Model:                            OLS   Adj. R-squared (uncentered):              0.846
# Method:                 Least Squares   F-statistic:                              1179.
# Date:                Tue, 18 May 2021   Prob (F-statistic):                    8.86e-89
# Time:                        15:48:23   Log-Likelihood:                         -1134.3
# No. Observations:                 214   AIC:                                      2271.
# Df Residuals:                     213   BIC:                                      2274.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Net Tim        0.0338      0.001     34.337      0.000       0.032       0.036
# ==============================================================================
# Omnibus:                      418.428   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.197
# Skew:                          -0.068   Prob(JB):                     0.000184
# Kurtosis:                       1.618   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
